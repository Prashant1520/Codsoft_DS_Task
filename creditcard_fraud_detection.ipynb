# %% [markdown]
#                                                              CODSOFT TASK 3

# %% [markdown]
#                                                      CREDIT CARD FRAUD DETECTION

# %% [raw]
# IMPORTING IMPORTANT LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
#                                                                  IMPORTING DATA SET

# %%
#Reading and viewing the data set of credit card
credits = pd.read_csv("creditcard.csv")
credits
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
credits.shape
# Out:
# (284807, 31)

# %%
#Viewing the starting 5 rows from the credit card data set
credits.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#Viewing the last 5 rows from the credit card dataset
credits.tail(5)
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  0.213454  0.111864
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.214205  0.924384
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.232045  0.578229
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.265245  0.800049
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
credits.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
credits.describe()
# Out:
#                   V1             V2             V3             V4  \
# count  275663.000000  275663.000000  275663.000000  275663.000000
# mean       -0.037460      -0.002430       0.025520      -0.004359
# std         1.952522       1.667260       1.507538       1.424323
# min       -56.407510     -72.715728     -48.325589      -5.683171
# 25%        -0.941105      -0.614040      -0.843168      -0.862847
# 50%        -0.059659       0.070249       0.200736      -0.035098
# 75%         1.294471       0.819067       1.048461       0.753943
# max         2.454930      22.057729       9.382558      16.875344
#
#                   V5             V6             V7             V8  \
# count  275663.000000  275663.000000  275663.000000  275663.000000
# mean       -0.010660      -0.014206       0.008586      -0.005698
# std         1.378117       1.313213       1.240348       1.191596
# min      -113.743307     -26.160506     -43.557242     -73.216718
# ...

# %%
#I want to see the description of the dataset while rounding up the floated fraction to 2 decimals.
#I also transpose the result to be able to see the entire columns
round(credits.describe(), 2).T
# Out:
#            count   mean     std     min   25%    50%    75%       max
# V1      275663.0  -0.04    1.95  -56.41 -0.94  -0.06   1.29      2.45
# V2      275663.0  -0.00    1.67  -72.72 -0.61   0.07   0.82     22.06
# V3      275663.0   0.03    1.51  -48.33 -0.84   0.20   1.05      9.38
# V4      275663.0  -0.00    1.42   -5.68 -0.86  -0.04   0.75     16.88
# V5      275663.0  -0.01    1.38 -113.74 -0.70  -0.06   0.60     34.80
# V6      275663.0  -0.01    1.31  -26.16 -0.77  -0.27   0.39     73.30
# V7      275663.0   0.01    1.24  -43.56 -0.55   0.04   0.58    120.59
# V8      275663.0  -0.01    1.19  -73.22 -0.21   0.02   0.32     20.01
# V9      275663.0  -0.01    1.10  -13.43 -0.66  -0.06   0.59     15.59
# V10     275663.0   0.00    1.09  -24.59 -0.54  -0.09   0.47     23.75
# V11     275663.0  -0.01    1.02   -4.80 -0.77  -0.04   0.73     12.02
# V12     275663.0  -0.01    1.00  -18.68 -0.41   0.13   0.61      7.85
# ...

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#Checking for any null values in the columns of the dataset
credits.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credits=credits.drop('Time',axis=1)

# %%
credits
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# ...

# %%
credits['Class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# 0 means not fraud and 1 means credit card fraud

# %%
#Checking the duplicate values
credits.duplicated().any()
# Out:
# True

# %%
#See the duplicated rows
credits[credits.duplicated()]
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 33     -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223  0.711206
# 35     -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983  0.693039
# 113     1.038370  0.127486  0.184456  1.109950  0.441699  0.945283 -0.036715
# 114     1.038370  0.127486  0.184456  1.109950  0.441699  0.945283 -0.036715
# 115     1.038370  0.127486  0.184456  1.109950  0.441699  0.945283 -0.036715
# ...          ...       ...       ...       ...       ...       ...       ...
# 284708  2.018105  0.073226 -1.615154  0.351058  0.333905 -0.676284  0.050474
# 284751  2.050734 -0.364010 -2.542843 -0.729357  2.388455  3.318015 -0.479138
# 284775  1.955547 -0.724606 -1.706511 -0.611145  1.710907  3.914215 -1.248690
# 284785  0.032887  0.545338 -1.185844 -1.729828  2.932315  3.401529  0.337434
# 284793  1.971002 -0.699067 -1.697541 -0.617643  1.718797  3.911336 -1.259306
#
# ...

# %%
#Remove the duplicate values from data set
credits.drop_duplicates(keep='first',inplace=True)

# %%
#there is no duplicate values we remove all duplicate values
credits.duplicated().sum()
# Out:
# 0

# %%
credits.shape
# Out:
# (275663, 30)

# %% [markdown]
#                                                                 CLASS VALUE COUNTS

# %%
credits["Class"].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
#Not Fraud
len(credits[credits['Class']==0])
# Out:
# 275190

# %%
#fraud
len(credits[credits['Class']==1])
# Out:
# 473

# %%
credits['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
sns.countplot(x=credits['Class'],hue=credits['Class'])
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
x=credits.drop('Class',axis=1)
y=credits['Class']

# %% [markdown]
#                                                         CREATING VISUALIZATION

# %%
ax=sns.countplot(data = credits, x= "Class", width=0.3)
ax.set_title("Distribution of transaction")
plt.xlabel("Type of transaction")
plt.ylabel("Number of transaction")


for i in ax.containers:
    ax.bar_label(i)

plt.show()

# %%
plt.figure(figsize = (20,12))
ax=sns.heatmap(credits.corr(), annot = True, fmt= '.2f')

for i in range(credits.shape[1]+1):
    ax.axvline(i, color='white', lw=2)
    ax.axhline(i, color='white', lw=2)

plt.show()

# %% [markdown]
#                                                         Appropriate model fitting

# %%
import statsmodels.api as sm

# %%
x1=sm.add_constant(x)
logit_model=sm.Logit(y,x1)
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.004029
#          Iterations 13
#                            Logit Regression Results
# ...
# Dep. Variable:                  Class   No. Observations:               275663
# Model:                          Logit   Df Residuals:                   275633
# Method:                           MLE   Df Model:                           29
# Date:                Sat, 09 Nov 2024   Pseudo R-squ.:                  0.6812
# Time:                        22:39:54   Log-Likelihood:                -1110.7
# converged:                       True   LL-Null:                       -3484.6
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -8.6967      0.152    -57.365      0.000      -8.994      -8.400
# ...

# %%
import scipy
from scipy.stats import chi2

# %%
chi2.pdf(4747.8,29)
#This value is less than 0.05 i.e our model is significant
# Out:
# 0.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x=credits.drop('Class',axis=1)
y=credits['Class'].ravel()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=22)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x=credits.drop('Class',axis=1)
#       2 y=credits['Class'].ravel()
#       3 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=22)
#
# AttributeError: '_Printer' object has no attribute 'drop'

# %%
len(x_train),len(x_test),len(y_train),len(y_test)
# Out:
# (220530, 55133, 220530, 55133)

# %%
Lreg=LogisticRegression(random_state=22)
Lreg.fit(x_train,y_train.ravel())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 Lreg=LogisticRegression(random_state=22)
# ----> 2 Lreg.fit(x_train,y_train.ravel())
#
# NameError: name 'x_train' is not defined

# %%
y_predict=Lreg.predict(x_test).ravel()
y_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#Our model is good fitted
Lreg.score(x_test,y_test)
# Out:
# 0.9992382057932636

# %%
#Create confussion matrix
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,y_predict)
score
# Out:
# 0.9992382057932636

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_predict)
# Out:
# array([[55050,     6],
#        [   36,    41]], dtype=int64)

# %%
tn,fp,fn,tp=confusion_matrix(y_test,y_predict).ravel()
print("True Negative",tn)
print("False Positive",fp)
print("False Negative",fn)
print("True Positive",tp)
# Out:
# True Negative 55050
# False Positive 6
# False Negative 36
# True Positive 41

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     55056
#            1       0.87      0.53      0.66        77
#
#     accuracy                           1.00     55133
#    macro avg       0.94      0.77      0.83     55133
# weighted avg       1.00      1.00      1.00     55133

# %%
Accuracy=(tp+tn)/(tp+tn+fp+fn)
print("Accuracy {:0.1f}".format(Accuracy))
# Out:
# Accuracy 1.0

# %%
Precision=(tp)/(tp+fp)
print("Precision:{:0.2f}".format(Precision))
# Out:
# Precision:0.87

# %%
Recall=tp/(tp+fn)
print("Sensitivity {:0.2f}".format(Recall))
# Out:
# Sensitivity 0.53

# %%
specifity=(tn)/(tn+fp)
print("specifity {:0.2f}.format(specifity)")
# Out:
# specifity {:0.2f}.format(specifity)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
x_test_predict=Lreg.predict(x_test)
ax = ConfusionMatrixDisplay.from_predictions(y_test,x_test_predict)
plt.show()
